# %% [markdown]
# <a href="https://colab.research.google.com/github/siomai1004/fa3program/blob/main/fa3programming.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
name = (input("Enter name"))
age = int(input("Enter age"))
course = (input("Enter course"))

print("Name: ", name)
print("Age: ", age)
print("Course: ", course)
# Out:
# Enter nameSiobhan
# Enter age13
# Enter coursePsychology
# Name:  Siobhan
# Age:  13
# Course:  Psychology

# %%
score = int(input("Enter score"))

if score >= 75:
 print("Passed")
elif score < 75:
 print("Failed")
# Out:
# Enter score80
# Passed

# %%
grade = int(input("Enter grade "))

if grade >= 90 and grade <=100:
 print("A")
elif grade < 90 and grade >= 80:
  print("B")
elif grade < 80 and grade >= 70:
 print("C")
else: grade < 70
print("F")
# Out:
# Enter grade 88
# B
# F
